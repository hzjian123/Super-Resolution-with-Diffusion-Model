# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
from model.sr3_modules.unet import UNet
print(UNet)
model = UNet(attn_res=[16
            ])
# Out:
# <class 'model.sr3_modules.unet.UNet'>
# Using early attention

# %%
path = "experiments/attention/checkpoint/I640000_E37_.pth"
state_dict = torch.load(path)
model.load_state_dict(state_dict)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\Eachann\Desktop\SR3\Image-Super-Resolution-via-Iterative-Refinement\attention.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Eachann/Desktop/SR3/Image-Super-Resolution-via-Iterative-Refinement/attention.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> path = "experiments/attention/checkpoint/I640000_E37_gen.pth"
#       <a href='vscode-notebook-cell:/c%3A/Users/Eachann/Desktop/SR3/Image-Super-Resolution-via-Iterative-Refinement/attention.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> state_dict = torch.load(path)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Eachann/Desktop/SR3/Image-Super-Resolution-via-Iterative-Refinement/attention.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> model.load_state_dict(state_dict)
#
# ...
